# %%
from requests import Session
from bs4 import BeautifulSoup as bs

# %% [markdown]
# Gets a response from ILS and checks if the request was successful (status code must be 2XX)

# %%
response = requests.get('https://www.ilsmart.com/')
print(response.status_code)
# Out:
# 200

# %%
soup = bs(response.text, 'html.parser')

# %% [markdown]
# Log into ILS

# %%
with Session() as s:
    site = s.get("https://www.ilsmart.com/ils-login")

# %% [markdown]
# Store cookies and info of the request session

# %%
    bs_content = bs(response.text, "html.parser")
    login_data = {"username":"cgb4u01","password":"amxgcgb4"}

# %% [markdown]
# Sends post request with parameters

# %%
    s.post("https://www.ilsmart.com/ils-login",login_data)
    home_page = s.get("https://www.ilsmart.com")
print(home_page.text)
# Out:
# <!doctype html><!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en" > <![endif]--><!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en" >        <![endif]--><!--[if IE 8]>    <html class="no-js lt-ie9" lang="en" >               <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en"><!--<![endif]--><head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="author" content="Inventory Locator Service,® LLC">
#     <meta name="description" content="ILSMart is the world's most dynamic aerospace parts marketplace. Register to find out why our next-gen technology &amp; tools are ideal for buyers and sellers.">
#     <meta name="generator" content="HubSpot">
#     <title>The World's Most Dynamic Aerospace Parts Marketplace | ILSMart</title>
#     <link rel="shortcut icon" href="https://www.ilsmart.com/hubfs/favicon.ico">
#
#
#
# ...
