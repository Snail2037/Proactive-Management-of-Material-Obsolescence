# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as ds

# %% [markdown]
# ## Loading in My Data
#
# Here I load in my data.

# %%
df = pd.read_csv("https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv")

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Grab Data From Individual Columns

# %%
df["temp"] = df["sepal_length"] + df["sepal_width"]

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  temp
# 0           5.1          3.5           1.4          0.2  setosa   8.6
# 1           4.9          3.0           1.4          0.2  setosa   7.9
# 2           4.7          3.2           1.3          0.2  setosa   7.9
# 3           4.6          3.1           1.5          0.2  setosa   7.7
# 4           5.0          3.6           1.4          0.2  setosa   8.6

# %%
df.iloc[4:10+1]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %%
df.groupby("species").agg(
    {
        "sepal_length": "mean",
        "sepal_width": lambda x: sum(x)/len(x)
    }
)
# Out:
#             sepal_length  sepal_width
# species
# setosa             5.006        3.418
# versicolor         5.936        2.770
# virginica          6.588        2.974

# %%
df.plot.scatter(x="sepal_length", y="sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ## Using Functions

# %%
def foo(x):
    return x+1

# %%
df["sepal_length"].apply(foo)
# Out:
# 0      6.1
# 1      5.9
# 2      5.7
# 3      5.6
# 4      6.0
#       ...
# 145    7.7
# 146    7.3
# 147    7.5
# 148    7.2
# 149    6.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df[["sepal_length", "sepal_width", "petal_length", "petal_width"]].apply(foo)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             6.1          4.5           2.4          1.2
# 1             5.9          4.0           2.4          1.2
# 2             5.7          4.2           2.3          1.2
# 3             5.6          4.1           2.5          1.2
# 4             6.0          4.6           2.4          1.2
# ..            ...          ...           ...          ...
# 145           7.7          4.0           6.2          3.3
# 146           7.3          3.5           6.0          2.9
# 147           7.5          4.0           6.2          3.0
# 148           7.2          4.4           6.4          3.3
# 149           6.9          4.0           6.1          2.8
#
# [150 rows x 4 columns]

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
